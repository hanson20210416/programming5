# %% [markdown]
# ### 2:sql

# %%
import pandas as pd
from sqlalchemy import create_engine, Column, Integer, Float, String, ForeignKey, text, MetaData
from sqlalchemy.orm import declarative_base, sessionmaker, relationship
from sqlalchemy.exc import SQLAlchemyError
from sqlalchemy.engine.url import URL

# %%
from sqlalchemy import create_engine, text
import pandas as pd

# Function to create the exam table with selected columns
def create_exam_table(engine):
    create_table_query = text("""
    CREATE TABLE IF NOT EXISTS student_data (
        school VARCHAR(5),
        sex CHAR(1),
        age TINYINT,
        address CHAR(1),
        Dalc TINYINT,
        Walc TINYINT
    )
    """)
    with engine.connect() as connection:
        connection.execute(create_table_query)
        connection.commit()

# Function to insert student data with selected columns
def insert_student_data(connection, student_data):
    insert_query = text("""
    INSERT INTO student_data (school, sex, age, address, Dalc, Walc)
    VALUES (:school, :sex, :age, :address, :Dalc, :Walc)
    """)
    
    try:
        connection.execute(insert_query, student_data)
        connection.commit()
    except Exception as error:
        print(f"Error inserting data: {str(error)}")

# Load CSV and insert data into the database
try:
    # Load data from CSV
    filepath = '/homes/zhe/Desktop/programming/p5/exam/SQL_example.csv'
    df = pd.read_csv(filepath)

    # Select only relevant columns
    selected_columns = ['school', 'sex', 'age', 'address', 'Dalc', 'Walc']
    df = df[selected_columns]

    # Replace NaN values with None for SQL compatibility
    df = df.where(pd.notna(df), None)

    # Connect to the database and insert data
    engine = create_engine('sqlite:////homes/zhe/Desktop/programming/p5/exam/file.db')
    
    create_exam_table(engine)

    with engine.connect() as connection:
        for _, row in df.iterrows():
            insert_student_data(connection, row.to_dict())

except Exception as e:
    print(f"An error occurred: {e}")

finally:
    if 'connection' in locals():
        connection.close()

# %%
from sqlalchemy import create_engine, text
import pandas as pd

def drop_table_if_exists(engine):
    with engine.connect() as connection:
        connection.execute(text("DROP TABLE IF EXISTS student_data"))
        connection.commit()
    print("Existing 'student_data' table dropped (if it existed)")


# Function to create the exam table with selected columns
def create_exam_table(engine):
    drop_table_if_exists(engine)
    
    create_table_query = text("""
    CREATE TABLE student_data (
        school VARCHAR(5),
        sex CHAR(1),
        age INTEGER,
        address CHAR(1),
        Dalc INTEGER,
        Walc INTEGER
    )
    """)
    with engine.connect() as connection:
        connection.execute(create_table_query)
        connection.commit()
    print("New 'student_data' table created")


def insert_student_data(connection, student_data):
    insert_query = text("""
    INSERT INTO student_data (school, sex, age, address, Dalc, Walc)
    VALUES (:school, :sex, :age, :address, :Dalc, :Walc)
    """)
    
    try:
        connection.execute(insert_query, student_data)
        connection.commit()
        print(f"Inserted data: {student_data}")
    except Exception as error:
        print(f"Error inserting data: {str(error)}")
        raise

try:
    # Load data from CSV
    filepath = '/homes/zhe/Desktop/programming/p5/exam/SQL_example.csv'
    df = pd.read_csv(filepath)

    # Select only relevant columns
    selected_columns = ['school', 'sex', 'age', 'address', 'Dalc', 'Walc']
    df = df[selected_columns]

    # Convert numeric columns to appropriate types
    df['age'] = pd.to_numeric(df['age'], errors='coerce')
    df['Dalc'] = pd.to_numeric(df['Dalc'], errors='coerce')
    df['Walc'] = pd.to_numeric(df['Walc'], errors='coerce')

    # Replace NaN values with None for SQL compatibility
    df = df.where(pd.notna(df), None)

    # Connect to the database and insert data
    engine = create_engine('sqlite:////homes/zhe/Desktop/programming/p5/exam/file.db')
    
    create_exam_table(engine)

    with engine.connect() as connection:
        for _, row in df.iterrows():
            try:
                insert_student_data(connection, row.to_dict())
            except Exception as e:
                print(f"Error inserting row: {row.to_dict()}")
                print(f"Error message: {str(e)}")

except Exception as e:
    print(f"An error occurred: {str(e)}")
    import traceback
    traceback.print_exc()

finally:
    if 'engine' in locals():
        engine.dispose()
# Out:
# Existing 'student_data' table dropped (if it existed)
# New 'student_data' table created
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 2, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 2, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'R', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 2, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 5, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 3, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'R', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'R', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'R', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'R', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 2, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 2, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 2, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 3, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 4, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'R', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 5, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 2, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 2, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 5, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'R', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'R', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'R', 'Dalc': 2, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 2, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 2, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 3, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'R', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'R', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 5, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'R', 'Dalc': 3, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'R', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'R', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'R', 'Dalc': 1, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 3, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 19, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'R', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'R', 'Dalc': 2, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'R', 'Dalc': 2, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'R', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'R', 'Dalc': 2, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 2, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 3, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 2, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'U', 'Dalc': 2, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 2, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 3, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 15, 'address': 'R', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 19, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'R', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'R', 'Dalc': 3, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'R', 'Dalc': 1, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'R', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 4, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'R', 'Dalc': 2, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 15, 'address': 'R', 'Dalc': 1, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 2, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'R', 'Dalc': 1, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 2, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 2, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 4, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'R', 'Dalc': 3, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'R', 'Dalc': 1, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 4, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'R', 'Dalc': 3, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'R', 'Dalc': 3, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'R', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'R', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 3, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 2, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'R', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 19, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 4, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 2, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'R', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 2, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 2, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'R', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 5, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'R', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 4, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'R', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 2, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 5, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'R', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 3, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'R', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 22, 'address': 'U', 'Dalc': 5, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'R', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 2, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 2, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 2, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 16, 'address': 'R', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'R', 'Dalc': 2, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 19, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'R', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'R', 'Dalc': 3, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 3, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'R', 'Dalc': 2, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'R', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 19, 'address': 'U', 'Dalc': 3, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'R', 'Dalc': 2, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'R', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 2, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 3, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'R', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'R', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'R', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 19, 'address': 'U', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 2, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 2, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 19, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 20, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 19, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 19, 'address': 'R', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 19, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 19, 'address': 'U', 'Dalc': 2, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 19, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 19, 'address': 'U', 'Dalc': 2, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 19, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 19, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 19, 'address': 'R', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'R', 'Dalc': 2, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 3, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'R', 'Dalc': 2, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 2, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 3, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 17, 'address': 'R', 'Dalc': 5, 'Walc': 5}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 2, 'Walc': 4}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'R', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'R', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 19, 'address': 'R', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'R', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 19, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 2, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'R', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'GP', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'GP', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'MS', 'sex': 'M', 'age': 18, 'address': 'R', 'Dalc': 5, 'Walc': 5}
# Inserted data: {'school': 'MS', 'sex': 'M', 'age': 19, 'address': 'R', 'Dalc': 3, 'Walc': 3}
# Inserted data: {'school': 'MS', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'MS', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'MS', 'sex': 'M', 'age': 19, 'address': 'R', 'Dalc': 3, 'Walc': 3}
# Inserted data: {'school': 'MS', 'sex': 'M', 'age': 17, 'address': 'R', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'MS', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'MS', 'sex': 'F', 'age': 17, 'address': 'R', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'MS', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'MS', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'MS', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'MS', 'sex': 'F', 'age': 18, 'address': 'R', 'Dalc': 1, 'Walc': 4}
# Inserted data: {'school': 'MS', 'sex': 'M', 'age': 18, 'address': 'R', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'MS', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'MS', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'MS', 'sex': 'F', 'age': 17, 'address': 'R', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'MS', 'sex': 'M', 'age': 18, 'address': 'R', 'Dalc': 2, 'Walc': 4}
# Inserted data: {'school': 'MS', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 2, 'Walc': 2}
# Inserted data: {'school': 'MS', 'sex': 'F', 'age': 17, 'address': 'R', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'MS', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'MS', 'sex': 'F', 'age': 18, 'address': 'R', 'Dalc': 4, 'Walc': 2}
# Inserted data: {'school': 'MS', 'sex': 'F', 'age': 19, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'MS', 'sex': 'M', 'age': 18, 'address': 'R', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'MS', 'sex': 'F', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'MS', 'sex': 'F', 'age': 17, 'address': 'R', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'MS', 'sex': 'F', 'age': 18, 'address': 'R', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'MS', 'sex': 'F', 'age': 18, 'address': 'R', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'MS', 'sex': 'F', 'age': 20, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'MS', 'sex': 'F', 'age': 18, 'address': 'R', 'Dalc': 3, 'Walc': 4}
# Inserted data: {'school': 'MS', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'MS', 'sex': 'F', 'age': 17, 'address': 'R', 'Dalc': 2, 'Walc': 3}
# Inserted data: {'school': 'MS', 'sex': 'M', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 4}
# Inserted data: {'school': 'MS', 'sex': 'M', 'age': 18, 'address': 'R', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'MS', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'MS', 'sex': 'M', 'age': 19, 'address': 'R', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'MS', 'sex': 'M', 'age': 18, 'address': 'R', 'Dalc': 4, 'Walc': 3}
# Inserted data: {'school': 'MS', 'sex': 'F', 'age': 18, 'address': 'R', 'Dalc': 1, 'Walc': 3}
# Inserted data: {'school': 'MS', 'sex': 'F', 'age': 18, 'address': 'R', 'Dalc': 2, 'Walc': 2}
# Inserted data: {'school': 'MS', 'sex': 'F', 'age': 19, 'address': 'R', 'Dalc': 1, 'Walc': 2}
# Inserted data: {'school': 'MS', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'MS', 'sex': 'F', 'age': 18, 'address': 'U', 'Dalc': 1, 'Walc': 1}
# Inserted data: {'school': 'MS', 'sex': 'M', 'age': 20, 'address': 'U', 'Dalc': 4, 'Walc': 5}
# Inserted data: {'school': 'MS', 'sex': 'M', 'age': 17, 'address': 'U', 'Dalc': 3, 'Walc': 4}
# Inserted data: {'school': 'MS', 'sex': 'M', 'age': 21, 'address': 'R', 'Dalc': 3, 'Walc': 3}
# Inserted data: {'school': 'MS', 'sex': 'M', 'age': 18, 'address': 'R', 'Dalc': 3, 'Walc': 4}
# Inserted data: {'school': 'MS', 'sex': 'M', 'age': 19, 'address': 'U', 'Dalc': 3, 'Walc': 3}

# %%
from sqlalchemy import create_engine, text

# Connect to the database
engine = create_engine('sqlite:////homes/zhe/Desktop/programming/p5/exam/file.db')

# Define the query
query = text("""
    SELECT 
        MAX(Dalc) AS Max_workday_intake,
        MAX(Walc) AS Max_weekend_intake
    FROM 
        student_data
""")

# Execute the query and fetch results
with engine.connect() as connection:
    result = connection.execute(query)
    row = result.fetchone()
    max_workday_intake = row[0]  # Accessing by index
    max_weekend_intake = row[1]  # Accessing by index

    # Determine when the maximum intake is higher
    if max_workday_intake > max_weekend_intake:
        print("The maximum alcohol consumption occurs during weekdays.")
    elif max_workday_intake < max_weekend_intake:
        print("The maximum alcohol consumption occurs during weekends.")
    else:
        print("The maximum alcohol consumption is the same for weekdays and weekends.")

    print(f"Max Workday Intake: {max_workday_intake}, Max Weekend Intake: {max_weekend_intake}")
# Out:
# The maximum alcohol consumption is the same for weekdays and weekends.
# Max Workday Intake: 5, Max Weekend Intake: 5

# %%
def drop_columns(engine, table_name, columns_to_drop):
    with engine.connect() as connection:
        for column in columns_to_drop:
            query = text(f"ALTER TABLE {table_name} DROP COLUMN {column}")
            connection.execute(query)
        connection.commit()

table_name = 'student_data'
columns_to_drop = ['school', 'address']

drop_columns(engine, table_name, columns_to_drop)

# %%
def show_table_structure(engine, table_name):
    with engine.connect() as connection:
        query = text(f"PRAGMA table_info({table_name})")
        result = connection.execute(query)
        columns = result.fetchall()
        
        print(f"\nStructure of table '{table_name}':")
        for column in columns:
            print(f"Column: {column[1]}, Type: {column[2]}")
table_name = 'student_data'
show_table_structure(engine, table_name)
# Out:
# Structure of table 'student_data':
# Column: sex, Type: CHAR(1)
# Column: age, Type: INTEGER
# Column: Dalc, Type: INTEGER
# Column: Walc, Type: INTEGER
